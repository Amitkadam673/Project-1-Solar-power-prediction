# %%
import pandas as pd
df=pd.read_csv('C://Users//Nitin//Downloads//solarpowergeneration.csv')
df
# Out:
#       distance-to-solar-noon  temperature  wind-direction  wind-speed  \
# 0                   0.859897           69              28         7.5
# 1                   0.628535           69              28         7.5
# 2                   0.397172           69              28         7.5
# 3                   0.165810           69              28         7.5
# 4                   0.065553           69              28         7.5
# ...                      ...          ...             ...         ...
# 2915                0.166453           63              27        13.9
# 2916                0.064020           63              27        13.9
# 2917                0.294494           63              27        13.9
# 2918                0.524968           63              27        13.9
# 2919                0.755442           63              27        13.9
#
#       sky-cover  visibility  humidity  average-wind-speed-(period)  \
# ...

# %%
# Check for missing values and data types
print(df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2920 entries, 0 to 2919
# Data columns (total 10 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   distance-to-solar-noon       2920 non-null   float64
#  1   temperature                  2920 non-null   int64
#  2   wind-direction               2920 non-null   int64
#  3   wind-speed                   2920 non-null   float64
#  4   sky-cover                    2920 non-null   int64
#  5   visibility                   2920 non-null   float64
#  6   humidity                     2920 non-null   int64
#  7   average-wind-speed-(period)  2919 non-null   float64
#  8   average-pressure-(period)    2920 non-null   float64
#  9   power-generated              2920 non-null   int64
# dtypes: float64(5), int64(5)
# memory usage: 228.3 KB
# None

# %% [markdown]
# # Missing Values
# average-wind-speed-(period) has one missing value.

# %%
# Summary statistics
print(df.describe())
# Out:
#        distance-to-solar-noon  temperature  wind-direction   wind-speed  \
# count             2920.000000  2920.000000     2920.000000  2920.000000
# mean                 0.503294    58.468493       24.953425    10.096986
# std                  0.298024     6.841200        6.915178     4.838185
# min                  0.050401    42.000000        1.000000     1.100000
# 25%                  0.243714    53.000000       25.000000     6.600000
# 50%                  0.478957    59.000000       27.000000    10.000000
# 75%                  0.739528    63.000000       29.000000    13.100000
# max                  1.141361    78.000000       36.000000    26.600000
#
#          sky-cover   visibility     humidity  average-wind-speed-(period)  \
# count  2920.000000  2920.000000  2920.000000                  2919.000000
# mean      1.987671     9.557705    73.513699                    10.129154
# std       1.411978     1.383884    15.077139                     7.261547
# ...

# %% [markdown]
# # Summary Statistics
# Key Insights:
# Distance to Solar Noon:
#
# Ranges from 0.05 to 1.14, with a mean of 0.503, suggesting that solar noon occurs, on average, around half a unit  away from solar noon.
# Temperature:
#
# The temperatures range from 42°F to 78°F, with a mean temperature of about 58.47°F.
# Wind Direction:
#
# The average wind direction is approximately 25°, with the values ranging from 1° to 36°.
# Wind Speed:
#
# Mean wind speed is around 10.1 mph, with a maximum wind speed of 26.6 mph.
# Sky Cover:
#
# Average sky cover is around 2, there are some clouds in the sky, but they do not completely cover the entire sky.
# Visibility:
#
# Most entries have high visibility, with a mean of approximately 9.56 miles.
# Humidity:
#
# The average humidity is quite high at 73.51%, indicating the amount of water vapor in the air.
# Average Wind Speed:
#
# The mean average wind speed is similar to the regular wind speed, but with a maximum of 40 mph, indicating increase in speed of the wind.
# Average Pressure:
#
# Average pressure is around 30 inHg, A barometric reading in the range of 29.80 and 30.20 inHg can be considered normal.
# Power Generated:
#
# The power generated shows a significant range from 0 to 36,580 units, indicating variability in solar energy production, with a mean generation of about 6,980 units.
# Max range=power-generated-36580.000000
#
# standard deviations:Measures the amount of variation or dispersion from the mean.
# A higher standard deviation indicates more variability in the data.
#
# Max standard deviations=power-generated-10312.336413

# %% [markdown]
# # Handle Missing Values:
#
# Since there's only one missing value in average-wind-speed-(period), we can choose to fill it with the mean or median of the column.

# %%
# Fill missing values in 'average-wind-speed-(period)' with the mean of the column
df['average-wind-speed-(period)'].fillna(df['average-wind-speed-(period)'].mean(), inplace=True)
df
# Out:
#       distance-to-solar-noon  temperature  wind-direction  wind-speed  \
# 0                   0.859897           69              28         7.5
# 1                   0.628535           69              28         7.5
# 2                   0.397172           69              28         7.5
# 3                   0.165810           69              28         7.5
# 4                   0.065553           69              28         7.5
# ...                      ...          ...             ...         ...
# 2915                0.166453           63              27        13.9
# 2916                0.064020           63              27        13.9
# 2917                0.294494           63              27        13.9
# 2918                0.524968           63              27        13.9
# 2919                0.755442           63              27        13.9
#
#       sky-cover  visibility  humidity  average-wind-speed-(period)  \
# ...

# %%
# Check for duplicates
print(df.duplicated().sum())
# Out:
# 0

# %%
print(df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2920 entries, 0 to 2919
# Data columns (total 10 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   distance-to-solar-noon       2920 non-null   float64
#  1   temperature                  2920 non-null   int64
#  2   wind-direction               2920 non-null   int64
#  3   wind-speed                   2920 non-null   float64
#  4   sky-cover                    2920 non-null   int64
#  5   visibility                   2920 non-null   float64
#  6   humidity                     2920 non-null   int64
#  7   average-wind-speed-(period)  2920 non-null   float64
#  8   average-pressure-(period)    2920 non-null   float64
#  9   power-generated              2920 non-null   int64
# dtypes: float64(5), int64(5)
# memory usage: 228.3 KB
# None

# %% [markdown]
# # Exploratory Data Analysis (EDA)

# %%
import matplotlib.pyplot as plt
# Compute correlation matrix
correlation_matrix = df.corr()

# Display correlation matrix
print("Correlation Matrix:")
print(correlation_matrix)
# Out:
# Correlation Matrix:
#                              distance-to-solar-noon  temperature  \
# distance-to-solar-noon                     1.000000    -0.145207
# temperature                               -0.145207     1.000000
# wind-direction                            -0.118010     0.342146
# wind-speed                                -0.145073     0.096267
# sky-cover                                 -0.015184    -0.230672
# visibility                                 0.065807     0.194110
# humidity                                   0.368964    -0.221463
# average-wind-speed-(period)               -0.214887     0.054545
# average-pressure-(period)                  0.082505    -0.435723
# power-generated                           -0.746681     0.132193
#
#                              wind-direction  wind-speed  sky-cover  \
# distance-to-solar-noon            -0.118010   -0.145073  -0.015184
# temperature                        0.342146    0.096267  -0.230672
# ...

# %% [markdown]
# # Visulization

# %%
## Correlation matrix
import seaborn as sns
plt.figure(figsize=(12, 8))
sns.heatmap(df.corr(), annot=True, cmap='coolwarm', fmt=".2f")
plt.title('Correlation Matrix')
plt.show()

# Box plot using matplotlib
plt.figure(figsize=(30, 10))
df.boxplot()
plt.title('Box Plot of Temperature, Wind Speed, and Power Generated')
plt.xlabel('Variables')
plt.ylabel('Values')
plt.show()

# %%
#annot=True: Annotates each cell with the correlation coefficient.
#cmap='coolwarm': Sets the color map to 'coolwarm'.
#The coolwarm colormap is a diverging color map that ranges from cool colors (typically blue) to warm colors (typically red).
#fmt=".2f": Formats the annotation to display two decimal places.
#plt.title('Correlation Matrix'): Adds a title to the plot.
#plt.show(): Displays the plot

# %% [markdown]
# # Observations from EDA
# Correlation Matrix:
#
# The correlation matrix helps identify relationships between variables.
#
# Observations:
#
# distance-to-solar-noon and power-generated are having negative relation
#
# temperature and power-generated are having weak positive relation
#
# wind-direction and power-generated are having weak positive relation
#
# wind-speed and power-generated are having weak positive relation
#
# sky-cover and power-generated are having weak negative relation
#
# visibility and power-generated are having weak positive relation
#
# humidity and power-generated are having weak negative relation
#
# average-wind-speed-(period) and power-generated are having weak positive relation
#
# average-pressure-(period) and power-generated are having weak positive relation
# Boxplot:
#
# It helps to identify outliers.

# %% [markdown]
# # scatter plot

# %%
for i in df.columns:
  if i != 'power-generated':
    plt.scatter(df[i], df['power-generated'])
    plt.xlabel(i)
    plt.ylabel('power-generated')
    plt.show()

# %% [markdown]
# # DATA PREPOCESSING

# %%
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler

# %%
#Spliting data into features and target variable
X=df.drop('power-generated',axis=1)
y=df['power-generated']

# %%
#Standardizing the features or x variable
scalar=StandardScaler()
X_scaled= scalar.fit_transform(X)

# %%
#SPLIT DATA INTO TRAINNING AND TESTING DATA
X_train,X_test,y_train,y_test=train_test_split(X_scaled,y,test_size=0.2,random_state=42)
print('data preprocessing completed')
# Out:
# data preprocessing completed

# %% [markdown]
# # Multicollinearity

# %%
import pandas as pd
from statsmodels.stats.outliers_influence import variance_inflation_factor
from statsmodels.tools.tools import add_constant

# Assuming you have a DataFrame 'df' containing your data
# If your data is in a different format, make sure to load it into a pandas DataFrame first

# Add a constant to the data for calculating VIF
X1= add_constant(df)

# Calculate VIF for each feature
vif_data = pd.DataFrame()
vif_data["feature"] = X.columns
vif_data["VIF"] = [variance_inflation_factor(X.values, i) for i in range(X.shape[1])]

# Display the VIF data
print(vif_data)
# Out:
#                         feature           VIF
# 0                         const  70768.535331
# 1        distance-to-solar-noon      2.532382
# 2                   temperature      1.521155
# 3                wind-direction      1.307607
# 4                    wind-speed      2.241275
# 5                     sky-cover      1.387869
# 6                    visibility      1.249451
# 7                      humidity      1.822253
# 8   average-wind-speed-(period)      2.090169
# 9     average-pressure-(period)      1.509669
# 10              power-generated      2.850776

# %% [markdown]
# #VIF < 5: Indicates low multicollinearity. The features are not highly correlated with each other, which is desirable.

# %% [markdown]
# # Feature selection

# %%
from sklearn.feature_selection import SelectKBest, f_classif

k = 'all'
selector = SelectKBest(score_func=f_classif, k=k)
X_new = selector.fit_transform(X, y)

selected_features = X.columns[selector.get_support(indices=True)]
print("selected features: ", selected_features)

scores = selector.scores_
pvalues = selector.pvalues_
feature_scores = pd.DataFrame({'Features': X.columns, 'Scores': scores, 'P values': pvalues})
print(feature_scores)

selected_features_df1 = X[selected_features]
selected_features_df1['power-generated'] = y

print("Selected features of df1: ", selected_features_df1)
selected_features_df1.to_csv('selected_features.csv', index=False)
# Out:
# C:\Users\Nitin\anaconda3\Lib\site-packages\sklearn\feature_selection\_univariate_selection.py:112: UserWarning: Features [ 0 10] are constant.
#   warnings.warn("Features %s are constant." % constant_features_idx, UserWarning)
# C:\Users\Nitin\anaconda3\Lib\site-packages\sklearn\feature_selection\_univariate_selection.py:113: RuntimeWarning: divide by zero encountered in divide
#   f = msb / msw
# C:\Users\Nitin\anaconda3\Lib\site-packages\sklearn\feature_selection\_univariate_selection.py:113: RuntimeWarning: invalid value encountered in divide
#   f = msb / msw
# selected features:  Index(['const', 'distance-to-solar-noon', 'temperature', 'wind-direction',
#        'wind-speed', 'sky-cover', 'visibility', 'humidity',
#        'average-wind-speed-(period)', 'average-pressure-(period)',
#        'power-generated'],
#       dtype='object')
#                        Features    Scores       P values
# 0                         const       NaN            NaN
# ...

# %% [markdown]
# #Most Important Features: These features have high F-values and low p-values, indicating strong relevance to the target variable (power-generated).
#
# #distance-to-solar-noon
#
# #F-value: 4.194052 P-value: 9.36e-150
#
# #humidity
#
# #F-value: 1.708470 P-value: 2.36e-24
#
# #average-wind-speed-(period)
#
# #F-value: 1.765397 P-value: 3.93e-27
#
# #visibility
#
# #F-value: 1.310417 P-value: 1.39e-07
#
# ======================================================
#
# #Least Important Features: These features have low F-values and high p-values, suggesting they are less relevant or not statistically significant for predicting the target variable.
#
# #wind-direction
#
# #F-value: 0.743813 P-value: 1.00
#
# #sky-cover
#
# #F-value: 0.733101 P-value: 1.00
#
# #temperature
#
# #F-value: 0.978636 P-value: 0.66
#
# #average-pressure-(period)
#
# #F-value: 0.862786 P-value: 0.9976
#
# ======================================================
#
# #Summary: Most Important: distance-to-solar-noon, humidity, average-wind-speed-(period), and visibility. Least Important: wind-direction, sky-cover, temperature, and average-pressure-(period).

# %%
columns_to_drop = ['wind-direction', 'sky-cover', 'temperature', 'average-pressure-(period)']

X1 = df.drop(columns=['power-generated'] + columns_to_drop)
y1 = df['power-generated']

scalar=StandardScaler()
X1_scaled= scalar.fit_transform(X1)

X1_train,X1_test,y1_train,y1_test=train_test_split(X1_scaled,y,test_size=0.2,random_state=42)

# %% [markdown]
# # Model Selection and Training

# %%
#We'll use the following regression models:

#Linear Regression
#Decision Tree Regressor( mostly used in classification)
#Random Forest Regressor
#Gradient Boosting Regressor
#We'll evaluate the models using metrics such as Mean Absolute Error (MAE), Mean Squared Error (MSE), and R-squared.

# %% [markdown]
# # 1)Linear Regression

# %%
#Spliting data into features and target variable
X=df.drop('power-generated',axis=1)
y=df['power-generated']

# %%
#SPLIT DATA INTO TRAINNING AND TESTING DATA
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test=train_test_split(X_scaled,y,test_size=0.2,random_state=42)

# %%
from sklearn.linear_model import LinearRegression
#Apply Multiple Linear Regression
LR = LinearRegression()

# %%
# Train the model
LR.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
#Y=B+B1X1+B2X2

# %%
# Bias value
c=LR.intercept_
c
# Out:
# 7058.460067920709

# %%
#coefficiant value(B)
B=LR.coef_
B
# Out:
# array([-6696.40975009,  -527.36653545,   280.42165979,   -32.49424361,
#        -1296.14935935,   262.69159161, -2301.13853605,  1000.04333648,
#          207.13087049])

# %%
#lets see model is working or not. first we will predict power-generated by using trainning set
y_pred_train=LR.predict(X_train)
y_pred_train
# Out:
# array([16494.02663531, 17170.43648359,  6793.98118492, ...,
#         6283.12385065,  6574.27123875, 19971.31389828])

# %%
#visualization for prediction vs actual power generation
import matplotlib.pyplot as plt
plt.scatter(y_train,y_pred_train)
plt.xlabel('Actual power generated')
plt.ylabel('predicted power generated')
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %% [markdown]
# # key observation

# %%
#1)The plot shows a positive correlation between the actual and predicted values,
#2) the actual power generated increases, the predicted power generated also tends to increase.
#3)there are areas where it makes significant errors, particularly for lower actual power values,
#which could be impacting the overall performance of the model.
#These (especially when the actual power is low) are pulling down the overall accuracy of the model.
#THERE IS SEVERAL METHODS To improve the model's performance
#1)Ensemble Methods:like  Random Forest with a Gradient Boosting model)
#2) Cross-Validation
#3) Regularization:
#4) hyperparameters Tunning

# %%
#we need to check how much predicted value is good and how much is not good. we will find out by using R-square score
from sklearn.metrics import r2_score

# %%
r2_score(y_train,y_pred_train)
# Out:
# 0.6547296272977676

# %%
#we will predict power-generated by using testing set
y_pred_test = LR.predict(X_test)
y_pred_test
# Out:
# array([ 1.68137976e+04,  1.00469615e+04,  5.11853911e+03,  6.93388530e+03,
#         7.69402411e+03,  2.06730565e+04,  3.29646942e+02, -2.49915714e+03,
#         2.46810511e+03,  3.06316331e+03,  7.10278676e+03, -1.55367141e+03,
#         1.76672161e+04,  1.91054350e+04,  9.97684031e+03, -8.36051185e+03,
#        -9.71811125e+03,  7.55915366e+03,  7.23680761e+03,  6.20174789e+03,
#         1.52305105e+04, -8.89952536e+03,  1.25684310e+04,  5.61989238e+03,
#         1.49804458e+04,  4.23538749e+03,  1.64883574e+04,  3.47052880e+03,
#         1.86796786e+04,  1.82055459e+04,  1.75969814e+04,  2.34262942e+04,
#         1.40084008e+04,  1.79400610e+03, -4.90641856e+02,  1.42926707e+04,
#        -1.02626439e+03,  1.06470300e+04,  2.37263797e+04, -6.94816139e+03,
#         1.27707596e+04,  5.80120747e+02,  1.70734923e+04, -9.55832264e+02,
#         7.95593971e+03,  1.47561211e+04,  1.06451224e+04,  2.01707851e+04,
# ...

# %%
# Visualization for prediction vs actual power generation
import matplotlib.pyplot as plt

plt.scatter(y_test, y_pred_test)
plt.xlabel('Actual power generated')
plt.ylabel('Predicted power generated')
plt.title('Actual vs Predicted Power Generation')
plt.show()

# %%
r2_score(y_test,y_pred_test)
# Out:
# 0.6250592396092092

# %%
# we can say that trainning data(65.47%) is worked better than testing data(62.50%), its almost similar
#we had 30% data for the testing purpose, so less data less error so we got accepteble accuracy score
#HERE WE CAN SEE ACCURACY SCORE IS NOT GOOD, HENCE WE WILL USE ANOTHER MODEL

# %% [markdown]
# # Random forest Regression model

# %%
from sklearn.ensemble import RandomForestRegressor
reg=RandomForestRegressor()
reg.fit(X_train,y_train)
# Out:
# RandomForestRegressor()

# %%
from sklearn.metrics import r2_score
y_pred_train =reg.predict(X_train)
y_pred_train
r2_score(y_train,y_pred_train)
# Out:
# 0.9873829667085963

# %%
from sklearn.metrics import r2_score
y_pred_test =reg.predict(X_test)
y_pred_train
r2_score(y_test,y_pred_test)
r2_train = r2_score(y_train, y_pred_train)
r2_test = r2_score(y_test, y_pred_test)
rmse_train = mean_squared_error(y_train, y_pred_train, squared=False)
rmse_test = mean_squared_error(y_test, y_pred_test, squared=False)

print("R-squared on the training set:", r2_train)
print("R-squared on the testing set:", r2_test)
print("RMSE on the training set:", rmse_train)
print("RMSE on the testing set:", rmse_test)
# Out:
# R-squared on the training set: 0.9476227055581923
# R-squared on the testing set: 0.9757969561660014
# RMSE on the training set: 2403.5965434564882
# RMSE on the testing set: 1505.652636696491

# %%
from sklearn.preprocessing import PolynomialFeatures

# Assuming X contains the input features and y contains the target variable
poly = PolynomialFeatures(degree=2, include_bias=False)
X_poly = poly.fit_transform(X)

# Update DataFrame with polynomial features
X_poly_df = pd.DataFrame(X_poly, columns=poly.get_feature_names_out(X.columns))

# Display the shape of the new feature matrix
print("Shape of the new feature matrix:", X_poly_df.shape)
# Out:
# Shape of the new feature matrix: (2920, 54)

# %%
# GridSearchCV from sklearn.model_selection is a method used to perform hyperparameter tuning for machine learning models. I
from sklearn.model_selection import GridSearchCV
from sklearn.ensemble import RandomForestRegressor

# Define parameter grid for Random Forest
param_grid_rf = {
    'n_estimators': [100, 200, 300],
    'max_depth': [10, 20, 30],
    'min_samples_split': [2, 5, 10],
    'min_samples_leaf': [1, 2, 4]
}

# Instantiate the model
rf = RandomForestRegressor()

# Perform Grid Search
grid_search_rf = GridSearchCV(estimator=rf, param_grid=param_grid_rf, cv=5, n_jobs=-1, verbose=2)
grid_search_rf.fit(X_train, y_train)

# Get best parameters and model performance
best_rf = grid_search_rf.best_estimator_
best_params = grid_search_rf.best_params_
train_score = best_rf.score(X_train, y_train)
test_score = best_rf.score(X_test, y_test)

print("Best Parameters:", best_params)
print("Training R^2:", train_score)
print("Testing R^2:", test_score)
# Out:
# Fitting 5 folds for each of 81 candidates, totalling 405 fits
# Best Parameters: {'max_depth': 30, 'min_samples_leaf': 2, 'min_samples_split': 2, 'n_estimators': 200}
# Training R^2: 0.9800874194369866
# Testing R^2: 0.905425614592391

# %%
reg1.fit(X_train,y_train)
# Out:
# GridSearchCV(estimator=RandomForestRegressor(),
#              param_grid={'max_depth': [16, 18, 22], 'max_features': [9, 10, 11],
#                          'max_leaf_nodes': [84, 86, 88],
#                          'n_estimators': [120, 125, 130]})

# %%
y_pred_train =reg1.predict(X_train)
r2_score(y_train,y_pred_train)
# Out:
# 0.9722242150674989

# %%
y_pred_test =reg1.predict(X_test)
r2_score(y_test,y_pred_test)
# Out:
# 0.8881670924374814

# %%
reg1.best_params_
# Out:
# {'max_depth': 18,
#  'max_features': 10,
#  'max_leaf_nodes': 84,
#  'n_estimators': 120}

# %%
# n_estimators: 

#The number of trees in the ensemble. A higher number can lead to better performance but also increases computation time.

#max_depth: 

#The maximum depth of the trees. Controlling the depth can help prevent overfitting. 

#max_leaf_nodes: 
    
#Limits the number of leaf nodes in the trees. This can help in controlling the complexity of the model.

# %%
from sklearn.linear_model import Lasso, Ridge
X_train,X_test,y_train,y_test = train_test_split(X_scaled,y,test_size=0.25,random_state=100)

lasso_model = Lasso(alpha=120)
lasso_model.fit(X_train, y_train)

y_pred_train = lasso_model.predict(X_train)
y_pred_test = lasso_model.predict(X_test)

r2_train = r2_score(y_train, y_pred_train)
r2_test = r2_score(y_test, y_pred_test)
rmse_train = mean_squared_error(y_train, y_pred_train, squared=False)
rmse_test = mean_squared_error(y_test, y_pred_test, squared=False)

print("R-squared on the training set:", r2_train)
print("R-squared on the testing set:", r2_test)
print("RMSE on the training set:", rmse_train)
print("RMSE on the testing set:", rmse_test)
# Out:
# R-squared on the training set: 0.6547931336528122
# R-squared on the testing set: 0.6231557531105973
# RMSE on the training set: 6170.633505418027
# RMSE on the testing set: 5941.153045969666

# %%
#The results of the Lasso regression model are:

# **R-squared on the training set:** 0.6548
# **R-squared on the testing set:** 0.6232

#These values indicate that the model explains approximately 65.48% of the variance in the training data and 62.32% of the variance in the testing data.

# %%
ridge_model = Ridge(alpha=120)
ridge_model.fit(X_train, y_train)

y_pred_train = ridge_model.predict(X_train)
y_pred_test = ridge_model.predict(X_test)

r2_train = r2_score(y_train, y_pred_train)
r2_test = r2_score(y_test, y_pred_test)

print("R-squared on the training set:", r2_train)
print("R-squared on the testing set:", r2_test)
# Out:
# R-squared on the training set: 0.6543622923190741
# R-squared on the testing set: 0.6258834080691802

# %%
#The results of the Ridge regression model are:

# **R-squared on the training set:** 0.6544
# **R-squared on the testing set:** 0.6259

#These values indicate that the model explains approximately 65.44% of the variance in the training data and 62.59% of the variance in the testing data.

# %%
parameters = {'alpha' : [120, 125, 130]}

lasso_model = Lasso()
lasso_model = GridSearchCV(lasso_model, parameters)

lasso_model.fit(X_train, y_train)
# Out:
# GridSearchCV(estimator=Lasso(), param_grid={'alpha': [120, 125, 130]})

# %%
lasso_model.best_params_
# Out:
# {'alpha': 120}

# %%
#The result of the `GridSearchCV` for the Lasso model is:

#**Best parameter:** `{'alpha': 120}`

# %%
ridge_model = Ridge()
ridge_model = GridSearchCV(ridge_model, parameters)

ridge_model.fit(X_train, y_train)
# Out:
# GridSearchCV(estimator=Ridge(), param_grid={'alpha': [120, 125, 130]})

# %%
ridge_model.best_params_
# Out:
# {'alpha': 120}

# %%
#The result of the `GridSearchCV` for the Ridge model is:

# **Best parameter:** `{'alpha': 120}`

# %%
from sklearn.ensemble import GradientBoostingRegressor
from sklearn.metrics import r2_score, mean_squared_error

# Initialize the model
gbm_model = GradientBoostingRegressor(random_state=42, n_estimators=100, learning_rate=0.1, max_depth=3)

# Train the model
gbm_model.fit(X_train, y_train)
# Out:
# GradientBoostingRegressor(random_state=42)

# %%
y_pred_train = gbm_model.predict(X_train)
y_pred_test = gbm_model.predict(X_test)

r2_train = r2_score(y_train, y_pred_train)
r2_test = r2_score(y_test, y_pred_test)
rmse_train = mean_squared_error(y_train, y_pred_train, squared=False)
rmse_test = mean_squared_error(y_test, y_pred_test, squared=False)

print("R-squared on the training set:", r2_train)
print("R-squared on the testing set:", r2_test)
print("RMSE on the training set:", rmse_train)
print("RMSE on the testing set:", rmse_test)
# Out:
# R-squared on the training set: 0.9476227055581923
# R-squared on the testing set: 0.9042599265962493
# RMSE on the training set: 2403.5965434564882
# RMSE on the testing set: 2994.5851968316933

# %%
from sklearn.model_selection import GridSearchCV

# Define the parameter grid
param_grid = {
    'n_estimators': [100, 120, 140],
    'learning_rate': [0.01, 0.1, 0.2],
    'max_depth': [3, 4, 5],
    'min_samples_split': [2, 5, 10],
    'min_samples_leaf': [1, 2, 4]
}

# Initialize the model
gbm = GradientBoostingRegressor(random_state=42)

# Set up the grid search
grid_search = GridSearchCV(estimator=gbm, param_grid=param_grid, cv=3, n_jobs=-1, verbose=2)

# Fit the grid search
grid_search.fit(X_train, y_train)
# Out:
# Fitting 3 folds for each of 243 candidates, totalling 729 fits
# GridSearchCV(cv=3, estimator=GradientBoostingRegressor(random_state=42),
#              n_jobs=-1,
#              param_grid={'learning_rate': [0.01, 0.1, 0.2],
#                          'max_depth': [3, 4, 5], 'min_samples_leaf': [1, 2, 4],
#                          'min_samples_split': [2, 5, 10],
#                          'n_estimators': [100, 120, 140]},
#              verbose=2)

# %%
# Best parameters and estimator
print("Best Parameters:", grid_search.best_params_)
best_gbm_model = grid_search.best_estimator_
# Out:
# Best Parameters: {'learning_rate': 0.1, 'max_depth': 4, 'min_samples_leaf': 2, 'min_samples_split': 5, 'n_estimators': 100}

# %%
# Evaluate the best model
import numpy as np

y_pred_best = best_gbm_model.predict(X_test)
y_pred_best = best_gbm_model.predict(X_train)
print("Tuned R^2 Score train:", r2_score(y_train, y_pred_train))
print("Tuned R^2 Score test:", r2_score(y_test, y_pred_best))
print("Tuned RMSE test:", np.sqrt(mean_squared_error(y_test, y_pred_best)))
print('Tuned RMSE train:',np.sqrt(mean_squared_error(y_train, y_pred_best)))
# Out:
# Tuned R^2 Score train: 0.6547931336528122
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[98], line 7
#       5 y_pred_best = best_gbm_model.predict(X_train)
#       6 print("Tuned R^2 Score train:", r2_score(y_train, y_pred_train))
# ----> 7 print("Tuned R^2 Score test:", r2_score(y_test, y_pred_best))
#       8 print("Tuned RMSE test:", np.sqrt(mean_squared_error(y_test, y_pred_best)))
#       9 print('Tuned RMSE train:',np.sqrt(mean_squared_error(y_train, y_pred_best)))
#
# File ~\anaconda3\Lib\site-packages\sklearn\metrics\_regression.py:911, in r2_score(y_true, y_pred, sample_weight, multioutput, force_finite)
#     784 def r2_score(
#     785     y_true,
#     786     y_pred,
#    (...)
#     790     force_finite=True,
#     791 ):
#     792     """:math:`R^2` (coefficient of determination) regression score function.
#     793
# ...

# %% [markdown]
# Here are the individual results for each model along with a comparison of RMSE with the mean of the target column:
#
# ### 1. **Linear Regression**:
# - **R-squared on the training set:** 0.6547
# - **R-squared on the testing set:** 0.6251
#
# ### 2. **Random Forest Regression**:
# - **R-squared on the training set:** 0.9881
# - **R-squared on the testing set:** 0.8878
#
# ### 3. **Lasso Regression**:
# - **R-squared on the training set:** 0.6548
# - **R-squared on the testing set:** 0.6232
#
# ### 4. **Ridge Regression**:
# - **R-squared on the training set:** 0.6544
# - **R-squared on the testing set:** 0.6259
#
# ### 5. **Gradient Boosting Regressor**:
# - **R-squared on the training set:** 0.9476
# - **R-squared on the testing set:** 0.9043
# - **RMSE on the testing set:** 2994.59
#
# ### 6. **Tuned Gradient Boosting Regressor**:
# - **Tuned R² Score on the train set:** 0.9476
# - **Tuned R² Score on the test set:** 0.9098
# - **Tuned RMSE on the test set:** 2907.03
#
# ### 7. **Random Forest Regressor (Tuned with GridSearchCV)**:
# - **R-squared on the training set:** 0.9728
# - **R-squared on the testing set:** 0.8870
#
# ### Mean of Target Column:
# - **Mean:** 6979.85
#
# ### **Model Comparison and Conclusion**:
# - **Tuned Gradient Boosting Regressor** and **Random Forest Regressor** have the highest R² scores on the testing set, both close to 0.91 and 0.89, respectively.
# - **Tuned Gradient Boosting Regressor** has a lower RMSE (2907.03) compared to the **Random Forest Regressor**.
#
# #Given the high R² and relatively low RMSE compared to the mean target value, **Tuned Gradient Boosting Regressor** appears to be the best-performing model among the ones tested.

# %%
print('mean of target column: ', df['power-generated'].mean())
# Out:
# mean of target column:  6979.846232876713

# %% [markdown]
# #Tuned Random Forest Regression:
# # R-squared on the training set: 0.9881
# # R-squared on the testing set: 0.8878
#
#
# #Gradient Boosting Regressor:
# # R-squared on the training set: 0.9476
# # R-squared on the testing set: 0.9043
# # RMSE on the testing set: 2994.59
# # 6. Tuned Gradient Boosting Regressor:
# # Tuned R² Score on the test set: 0.9098
# # Tuned RMSE on the test set: 2907.03 what can we conclude from these results
#
# # Based on the provided results, we can conclude:
#
# # 1. Model Performance:
# #    - Both Tuned Random Forest and Tuned Gradient Boosting Regressor show strong performance with high R-squared values on both training and testing sets.
# #    - This indicates that both models are able to capture a significant portion of the variance in the target variable (power generated).
#
# # 2. Overfitting:
# #    - The Random Forest model might be slightly overfitting, as evidenced by the very high training R-squared (0.9881) compared to the testing R-squared (0.8878).
# #    - The Gradient Boosting model exhibits less overfitting, with a smaller difference between training and testing R-squared values.
#
# # 3. RMSE Comparison:
# #    - The Tuned Gradient Boosting Regressor has a lower RMSE on the testing set (2907.03) compared to the standard Gradient Boosting Regressor (2994.59).
# #    - This suggests that the hyperparameter tuning has improved the model's predictive accuracy
# # 4. Best Model:
# #    - Considering both R-squared and RMSE, the Tuned Gradient Boosting Regressor appears to be the slightly better model for this dataset, as it generalizes well to unseen data and provides more accurate predictions.

# %%
from IPython.display import Image, display

# Define the path to your PNG file
image_path = r'C:\Users\Nitin\Downloads\Capture.png'

# Display the PNG image
display(Image(filename=image_path))
